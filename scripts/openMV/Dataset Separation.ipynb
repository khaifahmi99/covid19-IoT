# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import cv2 as cv
import seaborn as sns
import numpy as np

# %matplotlib inline

# %%
df = pd.read_csv('labels.csv')
df
# Out:
#      index  class
# 0        1      1
# 1        2      1
# 2        3      1
# 3        4      1
# 4        5      1
# ..     ...    ...
# 576    577      1
# 577    578      1
# 578    579      1
# 579    580      1
# 580    581      1
#
# [581 rows x 2 columns]

# %%
sns.countplot(df['class'])
# Out:
# /usr/local/Cellar/jupyterlab/2.2.8/libexec/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
# target class (associated with label col)

classes = [1, 3]

# %%
os.mkdir('fall_dataset')
for category in classes:
    os.mkdir('fall_dataset/' + str(category))

# %%
for category in classes:
    tdf = df[df['class'] == category] # filter dataset BY category
    
    for idx, row in tdf.iterrows():
        name = str(row['index'])
        name = name.zfill(4)
        im = cv.imread('rgb/rgb_' + name + '.png')
        cv2.imwrite('fall_dataset/' + category + '/' + name, im)
# Out:
# 0001
# [[[ 26  69 111]
#   [ 39  69 106]
#   [ 45  70 106]
#   ...
#   [ 18  37  42]
#   [ 16  31  58]
#   [ 10  24  57]]
#
#  [[ 16  67 123]
#   [ 27  70 113]
#   [ 34  74 113]
#   ...
#   [  6  41  51]
#   [  9  37  66]
#   [ 10  29  63]]
#
#  [[ 27  76 105]
#   [ 32  73 107]
#   [ 41  73 108]
#   ...
#   [  9  36  50]
#   [ 10  37  51]
#   [ 11  31  56]]
#
#  ...
#
#  [[ 24  49  77]
#   [ 10  44  72]
#   [ 19  39  75]
#   ...
#   [131 109 118]
#   [114 104 127]
#   [120  97 123]]
#
#  [[ 24  45  81]
#   [ 24  40  77]
#   [ 24  40  77]
#   ...
#   [136 114 103]
#   [120 105 127]
#   [118 101 123]]
#
#  [[ 27  47  52]
#   [ 43  41  66]
#   [ 35  39  75]
#   ...
#   [ 97  71  72]
#   [120 106 112]
#   [112  97 116]]]
#
#
# 0002
# [[[ 33  70  97]
#   [ 42  72  99]
#   [ 45  72 109]
#   ...
#   [ 20  36  60]
#   [ 20  35  53]
#   [ 17  30  36]]
#
#  [[ 35  71 102]
#   [ 37  74  98]
#   [ 36  76 100]
#   ...
#   [ 23  32  43]
#   [ 36  35  41]
#   [ 27  38  46]]
#
#  [[ 30  73 107]
# ...
